# %%
import pymysql as mysql
import pandas as pd
import numpy as np
import pickle

# %%
# pickle data import

df_inventors = pd.read_pickle('./samsung_inventors.pkl')
df_inventors[:10]

print(len(set((df_inventors['inventor_id']))))
# Out:
# 19698

# %%
# name_last and name_first Merge & upper string data

df_inventors['name'] = df_inventors['name_last'].str.upper() +' '+ df_inventors['name_first'].str.upper()
df_inventors['organization'] = df_inventors['organization'].str.upper()

# name_last and name_first drop & columns reindexing

df_inventors = df_inventors.drop(['name_last'],axis = 1)
df_inventors = df_inventors.drop(['name_first'],axis = 1)
df_inventors = df_inventors.reindex(columns=['inventor_id', 'name', 'organization', 'application_id', 'number'])

# %%
df_inventors[:500]
# Out:
#     inventor_id               name                         organization  \
# 0     7734988-3      KIM YUNG-SOO            SAMSUNG ELECTRONICS., LTD.
# 1     7986750-2      HWANG IN-SOO            SAMSUNG ELECTRONICS., LTD.
# 2     7808954-4      VAHID TAROKH            SAMSUNG ELECTRONICS., LTD.
# 3     7664087-1     YOU CHEOL-WOO            SAMSUNG ELECTRONICS., LTD.
# 4     7298797-4    NAM SEUNG-HOON            SAMSUNG ELECTRONICS., LTD.
# 5     4942447-2     CHOI BEOM-RAK          SAMSUNG ELECTRONICS CO. LTD.
# 6     5760814-1   KANG SOOK-YOUNG          SAMSUNG ELECTRONICS CO. LTD.
# 7     4945066-1    KANG MYUNG-KOO          SAMSUNG ELECTRONICS CO. LTD.
# 8     5105252-1      SONG JEAN-HO          SAMSUNG ELECTRONICS CO. LTD.
# 9     5105467-8     CHOI JOON-HOO          SAMSUNG ELECTRONICS CO. LTD.
# 10    6396981-2      CHOI JONG-HO         SAMSUNG ELECTRONICS CO., LTD.
# 11    6940573-1      CHOI NAK-CHO         SAMSUNG ELECTRONICS CO., LTD.
# ...

# %%
df_inventors['inventor_id'][df_inventors['inventor_id'] == '2001/20010036751-1']
# Out:
# 126575    2001/20010036751-1
# 229055    2001/20010036751-1
# 292982    2001/20010036751-1
# Name: inventor_id, dtype: object

# %%
#inventor_set = df_inventors.groupby('inventor_id')['name'].apply(lambda x : list(x)).reset_index()
#inventor_set = df_inventors[['inventor_id','name','organization','application_id','number']].groupby('inventor_id').agg("sum")

inventor_set = df_inventors.groupby('inventor_id').agg(lambda x : list(x)).reset_index()
#inventor_set = df_inventors.groupby('inventor_id').agg(lambda x : '~'.join(set(x))).reset_index()

# %%
inventor_set
# Out:
#               inventor_id                                               name  \
# 0      2001/20010006515-1  [PARK SUNG-BOK , PARK SUNG-BOK , PARK SUNG-BOK...
# 1      2001/20010008466-2         [KIM HEU-GON , KIM HEU-GON , KIM HEU-GON ]
# 2      2001/20010008466-3  [JANG JU-NYUNG , JANG JU-NYUNG , JANG JU-NYUNG...
# 3      2001/20010009863-1      [KIM YANG-SUN , KIM YANG-SUN , KIM YANG-SUN ]
# 4      2001/20010011020-1  [NAHM SEUNG-HYUN , NAHM SEUNG-HYUN , NAHM SEUN...
# 5      2001/20010011284-4  [HUMPLEMAN RICHARD JAMES, HUMPLEMAN RICHARD JA...
# 6      2001/20010012673-1  [GYU-CHUL KIM , GYU-CHUL KIM , GYU-CHUL KIM , ...
# 7      2001/20010012767-1                   [KIM HAN-SAENG , KIM HAN-SAENG ]
# 8      2001/20010017532-1                       [HAN JAY-HEE , HAN JAY-HEE ]
# 9      2001/20010018787-2                           [CHUNG U IN, CHUNG U IN]
# 10     2001/20010023942-1  [LEE SEONG-GUK , LEE SEONG-GUK , LEE SEONG-GUK...
# ...

# %%
inventor_set['name'] = inventor_set['name'][inventor_set["name"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-a8d92ca8e719> in <module>()
# ----> 1 inventor_set['name'] = inventor_set['name'][inventor_set["name"][0]]
#
# /home/jinhong/miniconda3/envs/ambiguation/lib/python3.5/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2417         else:
#    2418             # set column
# -> 2419             self._set_item(key, value)
#    2420
#    2421     def _setitem_slice(self, key, value):
#
# /home/jinhong/miniconda3/envs/ambiguation/lib/python3.5/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2483
#    2484         self._ensure_valid_index(value)
# -> 2485         value = self._sanitize_column(key, value)
#    2486         NDFrame._set_item(self, key, value)
#    2487
#
# ...

# %%
inventor_set["name"].dtypes
# Out:
# dtype('O')
